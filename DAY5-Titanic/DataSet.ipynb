# %% [markdown]
# <a href="https://colab.research.google.com/github/u2403126-gif/Internship/blob/main/DAY5-Titanic/DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO

# Read the file correctly
with open("test.csv", "r") as f:
    data = f.read()

# Remove extra quotes issue
data = data.replace('"', '')

# Convert to dataframe
df = pd.read_csv(StringIO(data))

# Show first 5 rows
print(df.head())
# Out:
#    version       team      continent  is_host  goals_scored_last_4y  \
# 0     2026     France         Europe        0                    85
# 1     2026      Spain         Europe        0                   104
# 2     2026  Argentina  South America        0                    80
# 3     2026    England         Europe        0                    82
# 4     2026   Portugal         Europe        0                    98
#
#    goals_received_last_4y  wins_last_4y  losses_last_4y  draws_last_4y  \
# 0                      32            25               6              7
# 1                      32            29               2              8
# 2                      14            30               4              3
# 3                      23            26               6              7
# 4                      31            26               5              7
#
#    world_cup_titles_before  ...  world_cup_participations_before  \
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (48, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   version                          48 non-null     int64
#  1   team                             48 non-null     object
#  2   continent                        48 non-null     object
#  3   is_host                          48 non-null     int64
#  4   goals_scored_last_4y             48 non-null     int64
#  5   goals_received_last_4y           48 non-null     int64
#  6   wins_last_4y                     48 non-null     int64
#  7   losses_last_4y                   48 non-null     int64
#  8   draws_last_4y                    48 non-null     int64
#  9   world_cup_titles_before          48 non-null     int64
#  10  squad_total_market_value_eur     48 non-null     int64
#  11  fifa_rank_pre_tournament         48 non-null     int64
# ...

# %%
print(df.isnull().sum())
# Out:
# version                             0
# team                                0
# continent                           0
# is_host                             0
# goals_scored_last_4y                0
# goals_received_last_4y              0
# wins_last_4y                        0
# losses_last_4y                      0
# draws_last_4y                       0
# world_cup_titles_before             0
# squad_total_market_value_eur        0
# fifa_rank_pre_tournament            0
# fifa_points_pre_tournament          0
# squad_avg_age                       0
# world_cup_participations_before     0
# groups_passed_before                0
# round16_before                      0
# quarterfinals_before                0
# semifinals_before                   0
# finals_before                       0
# winner                             48
# finalist                           48
# semi_finalist                      48
# quarter_finalist                   48
# dtype: int64

# %%
sns.countplot(x='continent', data=df)

plt.title("Teams by Continent")
plt.xticks(rotation=45)
plt.show()

# %%
sns.histplot(df['fifa_rank_pre_tournament'], bins=10)

plt.title("FIFA Rank Distribution")
plt.xlabel("FIFA Rank")
plt.ylabel("Count")
plt.show()

# %%
sns.kdeplot(df['goals_scored_last_4y'], fill=True)

plt.title("Goals Scored Distribution")
plt.xlabel("Goals Scored")
plt.show()

# %%
sns.scatterplot(
    x='wins_last_4y',
    y='losses_last_4y',
    hue='continent',
    data=df
)

plt.title("Wins vs Losses")
plt.show()

# %%
sns.histplot(df['squad_avg_age'], bins=10)

plt.title("Squad Average Age")
plt.xlabel("Average Age")
plt.show()

# %%
top_teams = df.sort_values(
    by='squad_total_market_value_eur',
    ascending=False
).head(10)

plt.figure(figsize=(10,5))

sns.barplot(
    x='team',
    y='squad_total_market_value_eur',
    data=top_teams
)

plt.xticks(rotation=45)
plt.title("Top 10 Teams by Market Value")
plt.show()

# %%
continent_counts = df['continent'].value_counts()

plt.figure(figsize=(7,7))

plt.pie(
    continent_counts,
    labels=continent_counts.index,
    autopct='%1.1f%%'
)

plt.title("Teams by Continent")
plt.show()
